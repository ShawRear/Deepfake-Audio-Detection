# %%
import librosa

# List of audio files
audio_files = ["/kaggle/input/forfake-or-real/for-norm/testing/real/file10.wav_16k.wav_norm.wav_mono.wav_silence.wav", "/kaggle/input/forfake-or-real/for-norm/testing/real/file1016.wav_16k.wav_norm.wav_mono.wav_silence.wav", "/kaggle/input/forfake-or-real/for-norm/validation/fake/file10069.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav"]

for audio_file in audio_files:
    # Load audio file
    y, sr = librosa.load(audio_file)
    
    # Print sample rate
    print(f"Sample Rate for {audio_file}: {sr}")
